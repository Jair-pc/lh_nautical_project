# %%
# %pip install pyarrow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 26.1.1
# [notice] To update, run: C:\Users\junio\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import pandas as pd

caminho = r"C:\Projeto\Indicium\lh_nautical_project\data\gold\dim_clientes.parquet"

dim_clientes = pd.read_parquet(caminho)

print(dim_clientes.head(5))
# Out:
#    id_cliente                         nome_completo  \
# 0           1            Femininos Oliveira Antunes
# 1           2  Fernanda Azevedo Soares Nunes Vieira
# 2           3        Daniel Farias Ribeiro Teixeira
# 3           4                        Thiago Moreira
# 4           5                         Pedro Freitas
#
#                                               email  email_valido  \
# 0             femininos.oliveira.antunes@icloud.com          True
# 1  nunes.fernanda.soares.azevedo.vieira@outlook.com          True
# 2          farias.teixeira.daniel.ribeiro#gmail.com         False
# 3                          thiago.moreira#gmail.com         False
# 4                          pedro.freitas#icloud.com         False
#
#              cidade estado
# 0  Aratu (Candeias)     BA
# 1            Recife     PE
# 2        Rio Grande     RS
# 3        Rio Branco     AC
# 4     Santarém Novo     PA

# %%
import pandas as pd

caminho = r"C:\Projeto\Indicium\lh_nautical_project\data\gold\dim_produtos.parquet"

dim_produtos = pd.read_parquet(caminho)

print(dim_produtos.head(5))
# Out:
#    id_produto                    nome_produto    categoria  preco_venda  \
# 0           1     Transponder AIS Maré Magnum  Eletrônicos     33122.52
# 1           2       Transponder Furuno Marlin  Eletrônicos     13998.15
# 2           3    Radar Furuno Pulse Leviathan  Eletrônicos      9024.19
# 3           4       Rádio AIS Hydro Tidal Zen  Eletrônicos      3381.88
# 4           5  Piloto Automático Furuno Storm  Eletrônicos     23669.01
#
#    custo_unitario_brl  margem_unitaria_pct
# 0            28456.72                14.09
# 1            13271.58                 5.19
# 2             8944.23                 0.89
# 3             2977.64                11.95
# 4            21855.03                 7.66

# %%
import pandas as pd

caminho = r"C:\Projeto\Indicium\lh_nautical_project\data\gold\fato_vendas.parquet"

fato_vendas = pd.read_parquet(caminho)

print(fato_vendas.head(5))
# Out:
#    id_venda data_venda  id_cliente  id_produto canal_venda status_venda  \
# 0         0 2023-09-10          42         105   ecommerce    concluida
# 1         1 2024-09-15           3         136   ecommerce    concluida
# 2         2 2024-08-13          25         139   ecommerce    concluida
# 3         4 2023-02-03          20          23   ecommerce    concluida
# 4         5 2024-02-12           8          57   ecommerce    concluida
#
#    quantidade  receita_bruta  desconto_pct  desconto_valor  receita_liquida  \
# 0          11         3405.0           0.0             0.0           3405.0
# 1           9        16873.9           0.0             0.0          16873.9
# 2           7         9475.3           0.0             0.0           9475.3
# 3           5        55893.0           0.0             0.0          55893.0
# 4           4       451403.9           0.0             0.0         451403.9
#
#    custo_total  lucro_bruto  margem_pct   ano  mes  trimestre dia_semana
# ...
